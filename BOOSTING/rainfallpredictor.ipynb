# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('weatherAUS_rainfall_prediction_dataset_cleaned.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        145460 non-null  float64
#  3   MaxTemp        145460 non-null  float64
#  4   Rainfall       145460 non-null  float64
#  5   Evaporation    145460 non-null  float64
#  6   Sunshine       145460 non-null  float64
#  7   WindGustDir    145460 non-null  object
#  8   WindGustSpeed  145460 non-null  float64
#  9   WindDir9am     145460 non-null  object
#  10  WindDir3pm     145460 non-null  object
#  11  WindSpeed9am   145460 non-null  float64
#  12  WindSpeed3pm   145460 non-null  float64
#  13  Humidity9am    145460 non-null  float64
#  14  Humidity3pm    145460 non-null  float64
#  15  Pressure9am    145460 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
df.head()
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2010-04-30  Adelaide     10.8     21.2       0.0          1.8      6.60
# 1  2014-07-22  Adelaide      3.7     19.0       0.0          1.4      7.61
# 2  2014-07-23  Adelaide      9.6     15.8       0.0          2.6      7.61
# 3  2014-07-24  Adelaide     10.1     15.5      16.6          0.8      7.61
# 4  2014-07-25  Adelaide     11.2     16.2       1.8          0.6      7.61
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0         ENE           22.0        ENE  ...        66.0         48.0
# 1           N           24.0          N  ...        75.0         32.0
# 2          NE           52.0        NNE  ...        35.0         51.0
# 3         NNE           50.0         NW  ...        96.0         80.0
# 4          NW           30.0        WNW  ...        89.0         70.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df['Location'].unique()
# Out:
# array(['Adelaide', 'Albany', 'Albury', 'AliceSprings', 'BadgerysCreek',
#        'Ballarat', 'Bendigo', 'Brisbane', 'Cairns', 'Canberra', 'Cobar',
#        'CoffsHarbour', 'Dartmoor', 'Darwin', 'GoldCoast', 'Hobart',
#        'Katherine', 'Launceston', 'Melbourne', 'MelbourneAirport',
#        'Mildura', 'Moree', 'MountGambier', 'MountGinini', 'Newcastle',
#        'Nhil', 'NorahHead', 'NorfolkIsland', 'Nuriootpa', 'PearceRAAF',
#        'Penrith', 'Perth', 'PerthAirport', 'Portland', 'Richmond', 'Sale',
#        'SalmonGums', 'Sydney', 'SydneyAirport', 'Townsville',
#        'Tuggeranong', 'Uluru', 'WaggaWagga', 'Walpole', 'Watsonia',
#        'Williamtown', 'Witchcliffe', 'Wollongong', 'Woomera'],
#       dtype=object)

# %%
df['WindGustDir'].unique()
# Out:
# array(['ENE', 'N', 'NE', 'NNE', 'NW', 'NNW', 'W', 'WSW', 'S', 'SSW', 'SW',
#        'WNW', 'SSE', 'SE', 'E', 'ESE'], dtype=object)

# %%
df['WindDir9am'].unique()
# Out:
# array(['ENE', 'N', 'NNE', 'NW', 'WNW', 'NNW', 'NE', 'SW', 'SE', 'WSW',
#        'SSW', 'S', 'ESE', 'E', 'W', 'SSE'], dtype=object)

# %%
df['RainToday'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['RainTomorrow'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall    Evaporation  \
# count  145460.000000  145460.000000  145460.000000  145460.000000
# mean       12.193993      23.221337       2.360898       5.468995
# std         6.365750       7.088124       8.382488       3.161541
# min        -8.500000      -4.800000       0.000000       0.000000
# 25%         7.700000      18.000000       0.000000       4.000000
# 50%        12.100000      22.700000       0.000000       5.470000
# 75%        16.800000      28.200000       1.000000       5.470000
# max        33.900000      48.100000     371.000000     145.000000
#
#             Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  145460.000000  145460.000000  145460.000000  145460.000000
# mean        7.610612      40.035567      14.043384      18.662601
# std         2.729486      13.118253       8.861059       8.716581
# min         0.000000       6.000000       0.000000       0.000000
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
models = {
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'GradientBoost': GradientBoostingClassifier(),
    'XGBoost': XGBClassifier()
}

# %%
df['Location'] = df['Location'].replace('MelbourneAirport', 'Melbourne')

# %%
df = df.drop(columns=['Date'])

# %%
df.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0  Adelaide     10.8     21.2       0.0          1.8      6.60         ENE
# 1  Adelaide      3.7     19.0       0.0          1.4      7.61           N
# 2  Adelaide      9.6     15.8       0.0          2.6      7.61          NE
# 3  Adelaide     10.1     15.5      16.6          0.8      7.61         NNE
# 4  Adelaide     11.2     16.2       1.8          0.6      7.61          NW
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0           22.0        ENE         NW  ...         66.0         48.0
# 1           24.0          N        NNE  ...         75.0         32.0
# 2           52.0        NNE         NE  ...         35.0         51.0
# 3           50.0         NW         NW  ...         96.0         80.0
# 4           30.0        WNW        WNW  ...         89.0         70.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
y = df['RainTomorrow']
df = df.drop(columns = ['RainTomorrow'], axis = 1)
df.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0  Adelaide     10.8     21.2       0.0          1.8      6.60         ENE
# 1  Adelaide      3.7     19.0       0.0          1.4      7.61           N
# 2  Adelaide      9.6     15.8       0.0          2.6      7.61          NE
# 3  Adelaide     10.1     15.5      16.6          0.8      7.61         NNE
# 4  Adelaide     11.2     16.2       1.8          0.6      7.61          NW
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  WindSpeed3pm  Humidity9am  \
# 0           22.0        ENE         NW  ...           7.0         66.0
# 1           24.0          N        NNE  ...          11.0         75.0
# 2           52.0        NNE         NE  ...          20.0         35.0
# 3           50.0         NW         NW  ...          26.0         96.0
# 4           30.0        WNW        WNW  ...          15.0         89.0
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
numeric_cols = [cols for cols in df.columns if df[cols].dtype != 'O']
cat_cols = [cols for cols in df.columns if df[cols].dtype == 'O']

# %%
numeric_cols
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustSpeed',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm']

# %%
cat_cols
# Out:
# ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
preprocessor = ColumnTransformer(transformers=[
    ('Scaler',StandardScaler(), numeric_cols),
    ('Encoder',OneHotEncoder(), cat_cols)
], remainder= 'passthrough'
)

# %%
x = df
x.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0  Adelaide     10.8     21.2       0.0          1.8      6.60         ENE
# 1  Adelaide      3.7     19.0       0.0          1.4      7.61           N
# 2  Adelaide      9.6     15.8       0.0          2.6      7.61          NE
# 3  Adelaide     10.1     15.5      16.6          0.8      7.61         NNE
# 4  Adelaide     11.2     16.2       1.8          0.6      7.61          NW
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  WindSpeed3pm  Humidity9am  \
# 0           22.0        ENE         NW  ...           7.0         66.0
# 1           24.0          N        NNE  ...          11.0         75.0
# 2           52.0        NNE         NE  ...          20.0         35.0
# 3           50.0         NW         NW  ...          26.0         96.0
# 4           30.0        WNW        WNW  ...          15.0         89.0
#
#    Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
y
# Out:
# 0          No
# 1          No
# 2         Yes
# 3         Yes
# 4         Yes
#          ...
# 145455     No
# 145456     No
# 145457     No
# 145458     No
# 145459     No
# Name: RainTomorrow, Length: 145460, dtype: object

# %%
y =LabelEncoder().fit_transform(y)
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state= 42)

# %%
x_train, x_test
# Out:
# (           Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
#  141565   Wollongong     13.7     24.3       0.0         5.47      7.61
#  85325     Nuriootpa     14.2     30.1       0.0         6.40      8.90
#  17847      Ballarat     13.4     21.9       0.0         5.47      7.61
#  69746   MountGinini      2.8      9.9       0.0         5.47      7.61
#  98356      Portland      7.3     13.5       4.0         1.60      8.90
#  ...             ...      ...      ...       ...          ...       ...
#  110268   SalmonGums      0.8     16.3       1.2         5.47      7.61
#  119879  Tuggeranong      0.8     16.2       0.0         5.47      7.61
#  103694     Richmond     14.6     28.2       0.0         2.80      7.61
#  131932     Watsonia     10.8     17.9       2.2         4.40      6.80
#  121958  Tuggeranong      5.3     13.9       0.2         5.47      7.61
#
#         WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  WindSpeed3pm  \
# ...

# %%
y_train, y_test
# Out:
# (array([0, 0, 0, ..., 0, 0, 0]), array([1, 0, 0, ..., 0, 0, 0]))

# %%
x_train_transformed = preprocessor.fit_transform(x_train)
x_test_transformed = preprocessor.fit_transform(x_test)

# %%
from sklearn.metrics import accuracy_score, recall_score, r2_score, precision_score,f1_score, classification_report

# %%
for key, model in models.items():
    model.fit(x_train_transformed, y_train)
    
    # Predictions
    y_train_pred = model.predict(x_train_transformed)
    y_test_pred = model.predict(x_test_transformed)

    print(f"\n================ {key} Model ================\n")

    # --- Training Performance ---
    print("Training Performance:")
    print(f"Accuracy:  {accuracy_score(y_train, y_train_pred)}")
    print(f"Precision: {precision_score(y_train, y_train_pred)}")
    print(f"Recall:    {recall_score(y_train, y_train_pred)}")
    print(f"F1 Score:  {f1_score(y_train, y_train_pred)}")

    # --- Testing Performance ---
    print("\nTesting Performance:")
    print(f"Accuracy:  {accuracy_score(y_test, y_test_pred)}")
    print(f"Precision: {precision_score(y_test, y_test_pred)}")
    print(f"Recall:    {recall_score(y_test, y_test_pred)}")
    print(f"F1 Score:  {f1_score(y_test, y_test_pred)}")

    # Optional: Detailed Report
    # print("\nClassification Report (Test Data):")
    # print(classification_report(y_test, y_test_pred))

    print("===============================================\n")
# Out:
# ================ Decision Tree Model ================
#
# Training Performance:
# Accuracy:  0.999970536819155
# Precision: 1.0
# Recall:    0.9998664411005254
# F1 Score:  0.9999332160904699
#
# Testing Performance:
# Accuracy:  0.7840185159723178
# Precision: 0.499500599280863
# Recall:    0.5311736590546999
# F1 Score:  0.5148504658465023
# ...
#
#
# ================ Random Forest Model ================
#
# Training Performance:
# Accuracy:  0.9999312525780283
# Precision: 1.0
# Recall:    0.9996883625678924
# F1 Score:  0.9998441570006902
#
# Testing Performance:
# Accuracy:  0.8558137403180714
# Precision: 0.7542745481191988
# Recall:    0.4919808815719596
# F1 Score:  0.5955258421187966
# ...
#
#
# ================ GradientBoost Model ================
#
# Training Performance:
# Accuracy:  0.8528117695586416
# Precision: 0.7493495229835212
# Recall:    0.5000445196331582
# F1 Score:  0.599823769725775
#
# Testing Performance:
# Accuracy:  0.8508410101287869
# Precision: 0.7284591194968554
# ...

# %%
rf_params = {
    'n_estimators': [100,200,300],
    'criterion': ['gini','entropy','log_loss'],
    'max_depth': [5, 8, 10, None],
    'min_samples_split': [2, 4, 5]
}
xgb_params = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [100, 300, 500],
    'colsample_bytree': [0.5, 0.8, 1],
    'subsample': [0.5, 0.8, 1],
    'gamma': [0, 1, 5]
}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
randomcv = [
    ('Random Forest', RandomForestClassifier(), rf_params),
    ('XGBClassifier', XGBClassifier(), xgb_params)
]

# %%
model_params = {}
for name,model,params in randomcv:
    random = RandomizedSearchCV(estimator=model, param_distributions=params, n_jobs=-1,n_iter = 100, cv = 3, verbose = 2)
    random.fit(x_train_transformed, y_train)

    model_params[name] = random.best_params_

    print(f"\n\n.........{name} best params........")
    print(model_params[name])
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
#
#
# .........Random Forest best params........
# {'n_estimators': 300, 'min_samples_split': 5, 'max_depth': None, 'criterion': 'gini'}
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
#
#
# .........XGBClassifier best params........
# {'subsample': 0.5, 'n_estimators': 500, 'max_depth': 7, 'learning_rate': 0.05, 'gamma': 1, 'colsample_bytree': 0.8}

# %%
modelss = {
    'Random Forest': RandomForestClassifier(n_estimators= 300, min_samples_split= 5, max_depth= None, criterion= 'gini'),
    'XGBoost': XGBClassifier(subsample= 0.5, n_estimators= 500, max_depth= 7, learning_rate= 0.05, gamma= 1, colsample_bytree= 0.8)
}

# %%
for key, values in modelss.items():
    model = values
    model.fit(x_train_transformed, y_train)

    y_pred = model.predict(x_test_transformed)

    print(f"- For {key} model")
    model_accuracy = accuracy_score(y_pred, y_test)
    print("...Accuracy Score: ", model_accuracy)
    model_precision = precision_score(y_pred, y_test)
    print("...Precision Score: ",model_precision)
    model_r2 = r2_score(y_pred, y_test)
    print("...R2 Score: ", model_r2)
    model_recall = recall_score(y_pred, y_test)
    print("...Recall Score: ", model_recall)
# Out:
# - For Random Forest model
# ...Accuracy Score:  0.8565928777670837
# ...Precision Score:  0.49739776951672865
# ...R2 Score:  -0.1750883288293028
# ...Recall Score:  0.7542277339346111
# - For XGBoost model
# ...Accuracy Score:  0.8611760392318621
# ...Precision Score:  0.551991502920871
# ...R2 Score:  -0.026392818574636934
# ...Recall Score:  0.7385249396049453

# %%
from sklearn.pipeline import Pipeline

# %%
model_pipe = Pipeline([
    ('first', preprocessor),
    ('second',XGBClassifier(subsample= 0.8, n_estimators= 500, max_depth= 7, learning_rate= 0.1, gamma= 0, colsample_bytree= 0.5))
])

# %%
model_pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('first',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Scaler', StandardScaler(),
#                                                   ['MinTemp', 'MaxTemp',
#                                                    'Rainfall', 'Evaporation',
#                                                    'Sunshine', 'WindGustSpeed',
#                                                    'WindSpeed9am',
#                                                    'WindSpeed3pm',
#                                                    'Humidity9am', 'Humidity3pm',
#                                                    'Pressure9am', 'Pressure3pm',
#                                                    'Cloud9am', 'Cloud3pm',
#                                                    'Temp9am', 'Temp3pm']),
#                                                  ('Encoder', OneHotEncoder(),
# ...

# %%
import pickle

# %%
with open('rainfall_predictor.pkl','wb') as file:
    pickle.dump(model_pipe, file)

# %%
with open('rainfall_predictor.pkl','rb') as f:
    loaded_model = pickle.load(f)

# %%
y_pred = loaded_model.predict(x_test)

# %%
# Out:
# 0.8622530821760851
